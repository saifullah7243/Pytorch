# %%
 # Step-1
 import torch

 x = torch.tensor(2.0, requires_grad=True)

# %%
# step 2
## define function
y = x**2 + 3 * x

# %%
## Step 3
## compute with .backward()
y.backward()

# %%
## Access
print(x.grad)
# Out:
# tensor(7.)

# %% [markdown]
# # Gradient Tracking in PyTorch
#
# In PyTorch:
#
# - `requires_grad=True` makes PyTorch track that tensor for gradients.
#
# After training, you may use:
#
# - `x.detach()` → to get a tensor without gradient tracking.
#
# - `with torch.no_grad():` → to turn off gradient tracking during inference.
#
# ---
#
# ## 🔧 `requires_grad=True`
#
# Setting `requires_grad=True` on a tensor tells PyTorch to start tracking all operations on it. This is necessary for computing gradients during the backward pass.
#
# ```python
# import torch
#
# x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
